# %%
import pandas as pd
import csv

# %%
Data = pd.read_csv('./weather/新北市資料/466880-2013-01-02.csv',skiprows=1)
date = '2013-01-02'
Data['Date'] = date
Data
# Out:
#     ObsTime  StnPres  SeaPres  Temperature  Td dew point  RH   WS   WD
# 0         1   1017.9   1019.2         14.5          12.5  88  2.0   30  \
# 1         2   1017.8   1019.1         14.8          12.6  87  1.1   30
# 2         3   1017.3   1018.6         14.9          12.5  86  1.1   20
# 3         4   1017.2   1018.5         15.1          12.7  86  0.7  350
# 4         5   1017.2   1018.5         14.5          12.6  88  0.1    0
# 5         6   1018.1   1019.4         14.4          12.5  88  1.2  200
# 6         7   1018.7   1020.0         14.4          12.5  88  0.9  190
# 7         8   1019.3   1020.6         14.9          12.9  88  0.8  170
# 8         9   1019.7   1021.0         16.2          13.4  83  0.1    0
# 9        10   1020.2   1021.5         17.3          14.2  82  0.2    0
# 10       11   1019.6   1020.9         18.9          14.8  77  0.8  250
# 11       12   1019.4   1020.7         19.5          14.2  71  1.6  210
# ...

# %%
cols = list(Data.columns)
cols = ['Date'] + cols[:-1]
Data = Data[cols]
Data
# Out:
#           Date  ObsTime  StnPres  SeaPres  Temperature  Td dew point  RH   WS
# 0   2013-01-02        1   1017.9   1019.2         14.5          12.5  88  2.0  \
# 1   2013-01-02        2   1017.8   1019.1         14.8          12.6  87  1.1
# 2   2013-01-02        3   1017.3   1018.6         14.9          12.5  86  1.1
# 3   2013-01-02        4   1017.2   1018.5         15.1          12.7  86  0.7
# 4   2013-01-02        5   1017.2   1018.5         14.5          12.6  88  0.1
# 5   2013-01-02        6   1018.1   1019.4         14.4          12.5  88  1.2
# 6   2013-01-02        7   1018.7   1020.0         14.4          12.5  88  0.9
# 7   2013-01-02        8   1019.3   1020.6         14.9          12.9  88  0.8
# 8   2013-01-02        9   1019.7   1021.0         16.2          13.4  83  0.1
# 9   2013-01-02       10   1020.2   1021.5         17.3          14.2  82  0.2
# 10  2013-01-02       11   1019.6   1020.9         18.9          14.8  77  0.8
# ...

# %%
type(Data)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv('./weather.csv')
date = data['whole_date']
data['whole_date'] = pd.to_datetime(data['whole_date'])
type(date.iloc[1])
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_3880\107442236.py:1: DtypeWarning: Columns (3,4,5,6,7,8,10,11,13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./weather.csv')
# str

# %%
from datetime import datetime, timedelta,date
start_time = pd.Timestamp('2017-01-01')
end_time = pd.Timestamp('2023-12-31')
filtered_data = data[(data['whole_date'] >= start_time) & (data['whole_date'] <= end_time)]
filtered_data
# Out:
#         Station_ID whole_date  ObsTime StnPres SeaPres Temperature
# 34970       466880 2017-01-01        1  1021.4  1022.7        20.2  \
# 34971       466880 2017-01-01        2  1020.7    1022        20.3
# 34972       466880 2017-01-01        3  1020.2  1021.5        20.5
# 34973       466880 2017-01-01        4  1019.9  1021.2        20.4
# 34974       466880 2017-01-01        5  1020.2  1021.5        20.2
# ...            ...        ...      ...     ...     ...         ...
# 182085      466920 2023-05-23       20  1009.8  1013.4        21.9
# 182086      466920 2023-05-23       21  1009.7  1013.3        21.7
# 182087      466920 2023-05-23       22  1009.9  1013.5        21.7
# 182088      466920 2023-05-23       23  1009.6  1013.2        21.7
# 182089      466920 2023-05-23       24  1008.7  1012.3        21.5
#
#        Td_dew_point  RH   WS   WD WSGust WDGust Precp PrecpHour SunShine
# 34970          14.5  70  2.5   60    5.8     80     0         0      ...  \
# ...
